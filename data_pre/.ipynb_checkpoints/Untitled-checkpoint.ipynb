# %%
import numpy as np
import json
from pycocotools.coco import COCO

mpii=COCO('mpii_train.json')
# Out:
# loading annotations into memory...
# Done (t=0.99s)
# creating index...
# index created!

# %%
img_ids=mpii.getImgIds()
ann_ids=mpii.getAnnIds(img_ids[2])
ann_infos=mpii.loadAnns(ann_ids)
print(img_ids[2])
for ann_info in ann_infos:
    print(ann_info)
# Out:
# 7
# [{'id': 12, 'image_id': 7, 'bbox': [22.865108574061196, 84.8651085740612, 559.1348914259388, 621.1348914259388], 'keypoints': [[301.0, 461.0, 1.0], [305.0, 375.0, 1.0], [201.0, 340.0, 1.0], [294.0, 342.0, 0.0], [335.0, 370.0, 0.0], [331.0, 455.0, 1.0], [248.0, 341.0, 0.0], [279.0, 263.0, 1.0], [277.021, 268.7786, 0.0], [305.979, 184.2214, 0.0], [328.0, 354.0, 1.0], [260.0, 335.0, 1.0], [244.0, 261.0, 1.0], [314.0, 264.0, 1.0], [327.0, 320.0, 1.0], [362.0, 346.0, 0.0]], 'num_keypoints': 14}, {'id': 13, 'image_id': 7, 'bbox': [220.46900787378115, 125.46900787378115, 720.0, 628.5309921262188], 'keypoints': [[515.0, 512.0, 1.0], [514.0, 420.0, 1.0], [406.0, 388.0, 1.0], [392.0, 360.0, 0.0], [493.0, 434.0, 0.0], [518.0, 504.0, 1.0], [399.0, 374.0, 0.0], [498.0, 317.0, 1.0], [504.5953, 315.1758, 0.0], [585.4047, 292.8242, 0.0], [628.0, 426.0, 1.0], [551.0, 398.0, 1.0], [501.0, 351.0, 1.0], [495.0, 282.0, 1.0], [425.0, 301.0, 1.0], [483.0, 334.0, 1.0]], 'num_keypoints': 14}]
